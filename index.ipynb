# %% [markdown]
# # Hello World

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import cv2

# %%
image = cv2.imread('dataset/IMG_1.jpeg')

# %%
plt.figure()
plt.title("Image 1")
plt.imshow(image, cmap=plt.cm.gray)

# %%
image.shape
# Out:
# (3024, 4032, 3)
